# %%
import requests
import json
import time
import random
import os
import pandas as pd

# %%
from dotenv import load_dotenv
from datetime import datetime, timedelta
from pytz import timezone

load_dotenv()

BEARERTOKEN = os.getenv('BEARERTOKEN')

# %% [markdown]
# Source Code : https://medium.com/data-analytics-at-nesta/all-you-need-to-get-started-with-twitter-api-v2-using-python-6cd4be4d90fe

# %%
# Endpoint URL
endpoint_url = "https://api.twitter.com/2/tweets/search/recent"

#Timed settings with ISO 8601 format
local_time = timezone("Asia/Jakarta").localize(datetime(2025, 1, 27, 19, 0, 0))
start_time = local_time.astimezone(timezone("UTC")).strftime("%Y-%m-%dT%H:%M:%SZ")

# %%
#YYYY-MM-DDTHH:mm:ssZ
start_time
# Out:
# '2025-01-27T12:00:00Z'

# %%
# Query parameters
#query_parameters = {
#    "query": '("makan bergizi gratis" OR "makan siang gratis" OR "MBG") lang:id -is:retweet',
#    "tweet.fields": "id,text,author_id,created_at",
#    "start_time": start_time,
#    "max_results": 10,
#}

# %%
def request_headers(bearer_token: str) -> dict:
    """
    Sets up the request headers. 
    Returns a dictionary summarising the bearer token authentication details.
    """
    return {"Authorization": "Bearer {}".format(bearer_token)}

headers = request_headers(BEARERTOKEN)

# %%
def connect_to_endpoint(endpoint_url: str, headers: dict, parameters: dict) -> json:
    """
    Connects to the endpoint and requests data.
    Returns a json with Twitter data if a 200 status code is yielded.
    Programme stops if there is a problem with the request and sleeps
    if there is a temporary problem accessing the endpoint.
    """
    response = requests.request(
        "GET", url=endpoint_url, headers=headers, params=parameters
    )
    response_status_code = response.status_code
    if response_status_code != 200:
        if response_status_code >= 400 and response_status_code < 500:
            raise Exception(
                "Cannot get data, the program will stop!\nHTTP {}: {}".format(
                    response_status_code, response.text
                )
            )
        
        sleep_seconds = random.randint(5, 60)
        print(
            "Cannot get data, your program will sleep for {} seconds...\nHTTP {}: {}".format(
                sleep_seconds, response_status_code, response.text
            )
        )
        time.sleep(sleep_seconds)
        return connect_to_endpoint(endpoint_url, headers, parameters)
    return response.json()

#uncomment to execute
#json_response = connect_to_endpoint(endpoint_url, headers, query_parameters)

# %%
#set up rules
#rules = [
#    {"value": '("makan bergizi gratis" OR "makan siang gratis" OR "MBG") lang:id -is:retweet', "tag": "mbg"},
#]

# %%
def process_twitter_data(
    json_response: json,
    query_tag: str,
    tweets_data: pd.DataFrame,
    users_data: pd.DataFrame,
) -> (pd.DataFrame, pd.DataFrame):
    """
    Adds new tweet/user information to the table of
    tweets/users and saves dataframes as pickle files,
    if data is avaiable.
    
    Returns the tweets and users updated dataframes.
    """
    if "data" in json_response.keys():
        new = pd.DataFrame(json_response["data"])
        tweets_data = pd.concat([tweets_data, new])
        tweets_data.to_pickle("tweets_" + query_tag + ".pkl")

        #json_response["includes"] return error, disabling for now
        #if "users" in json_response["includes"].keys():
        #    new = pd.DataFrame(json_response["includes"]["users"])
        #    users_data = pd.concat([users_data, new])
        #    users_data.drop_duplicates("id", inplace=True)
        #    users_data.to_pickle("users_" + query_tag + ".pkl")

    return tweets_data, users_data

# %%
query_parameters = {
    "tweet.fields": "id,text,author_id,created_at",
    "user.fields": "id,name,username,created_at,description,location,verified",
    "start_time": start_time,
    "max_results": 99,
}

# %%
rules = [
    {"value": '("makan bergizi gratis" OR "makan siang gratis" OR "MBG") lang:id -is:retweet', "tag": "mbg"},
]

# %%
tweets_data = pd.DataFrame()
users_data = pd.DataFrame()

for i in range(len(rules)):
    query_parameters["query"] = rules[i]["value"]
    query_tag = rules[i]["tag"]

    json_response = connect_to_endpoint(endpoint_url, headers, query_parameters)
    tweets_data, users_data = process_twitter_data(
        json_response, query_tag, tweets_data, users_data
    )

    time.sleep(20)

    while "next_token" in json_response["meta"]:
        query_parameters["next_token"] = json_response["meta"]["next_token"]

        json_response = connect_to_endpoint(endpoint_url, headers, query_parameters)
        tweets_data, users_data = process_twitter_data(
            json_response, query_tag, tweets_data, users_data
        )

        time.sleep(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 9
#       6 query_tag = rules[i]["tag"]
#       8 json_response = connect_to_endpoint(endpoint_url, headers, query_parameters)
# ----> 9 tweets_data, users_data = process_twitter_data(
#      10     json_response, query_tag, tweets_data, users_data
#      11 )
#      13 time.sleep(20)
#      15 while "next_token" in json_response["meta"]:
#
# Cell In[6], line 19, in process_twitter_data(json_response, query_tag, tweets_data, users_data)
#      16 tweets_data = pd.concat([tweets_data, new])
#      17 tweets_data.to_pickle("tweets_" + query_tag + ".pkl")
# ---> 19 if "users" in json_response["includes"].keys():
#      20     new = pd.DataFrame(json_response["includes"]["users"])
#      21     users_data = pd.concat([users_data, new])
#
# KeyError: 'includes'

# %%
json_response

# %%
## ganti nama file

with open('jsonresponse3.json', 'w') as fp: 
    json.dump(json_response, fp)

# %%
resultdf = pd.DataFrame(columns=['id', 'edit_history_tweet_ids', 'created_at', 'text', 'author_id'])

for i in range(len(json_response['data'])):
    #print(json_response['data'][i])
    insertdf = pd.DataFrame(json_response['data'][i])
    resultdf = pd.concat([resultdf,insertdf])

# %%
resultdf

# %%
json_response
# Out:
# {'data': [{'text': 'ril MBG 😭😭😭 https://t.co/kGHHXWho5c',
#    'author_id': '1273934862215335937',
#    'id': '1886107824356561286',
#    'created_at': '2025-02-02T17:42:02.000Z',
#    'edit_history_tweet_ids': ['1886107824356561286']},
#   {'text': '@pengardian sekarang udah 36k, makan siang gratis could never',
#    'author_id': '1857048752248209408',
#    'id': '1886106735632609613',
#    'created_at': '2025-02-02T17:37:42.000Z',
#    'edit_history_tweet_ids': ['1886106735632609613']},
#   {'text': '@abulmuzaffar10 gua yakin, ini mbg buat bikin rusuh di kulit. buat pembiasan hal yg lebih penting.',
#    'author_id': '1632409274373791744',
#    'id': '1886106107925626938',
#    'created_at': '2025-02-02T17:35:12.000Z',
#    'edit_history_tweet_ids': ['1886106107925626938']},
#   {'text': 'Ternyata gak kaleng² isinya, nasi putih, sepotong ayam bakar, sambal, kriuk selada, timun &amp; daun kol juga masih diberi segelas air mineral, cuma 11.655 rupiah udah dianter @gojekindonesia pula\nLebih enak dari menu makan bergizi gratis deh 😜\n\nMakasih GO-JEK \nCc presiden @prabowo https://t.co/2cMqMYYxhH https://t.co/mkk1hA2gAS',
#    'author_id': '2755262034',
#    'id': '1886105395082788888',
#    'created_at': '2025-02-02T17:32:22.000Z',
#    'edit_history_tweet_ids': ['1886105395082788888']},
#   {'text': 'Alasannya biar subsidi tepat sasaran. Tapi tujuan sebenarnya sama2 tau lah kita, mau berhemat. Demi MBG. Demi bayarin utang2 peninggalan Jokowi dan segala PSN-nya yg bermasalah.\n\nDg alasan yg sama, rakyat sdh berhasil dipersulit membeli Pertalite. Sekarang giliran LPG 3kg.',
#    'author_id': '2990543688',
#    'id': '1886105273775141263',
#    'created_at': '2025-02-02T17:31:54.000Z',
#    'edit_history_tweet_ids': ['1886105273775141263']},
#   {'text': '@ruhendie @Mdy_Asmara1701 Semuanya dibuat susah.\n\nYg penting makan bergizi gratis.\n\nMenterinya banyak tapi kerjaannya gak jelas dan bikin repot rakyat 🤣🤣\n\nKesel dah',
#    'author_id': '1435645751120433154',
#    'id': '1886105097832468751',
#    'created_at': '2025-02-02T17:31:12.000Z',
#    'edit_history_tweet_ids': ['1886105097832468751']},
#   {'text': '@R19cakra @sutanmangara Program MBG itu termasuk salah satunya yang konyol pak, tolong ditinjau ulang.',
#    'author_id': '1057048956',
#    'id': '1886104384414863417',
#    'created_at': '2025-02-02T17:28:22.000Z',
#    'edit_history_tweet_ids': ['1886104384414863417']},
#   {'text': '@WisanggeniLagi Seteju ya klw begini makanannya bang ?????\nBukannya setuju klw serangga yg dijadikan MBG🤭😛',
#    'author_id': '1855186426763284481',
#    'id': '1886104178759757986',
#    'created_at': '2025-02-02T17:27:32.000Z',
#    'edit_history_tweet_ids': ['1886104178759757986']},
#   {'text': '@prabowo @KPK_RI program MBG ini hrs bnr2 diawasi langsung klo ga banyak kejadian sprti ini, dan kod oknum2 ini hrs diproses hukum dg tegas https://t.co/ucECe3TPnY',
#    'author_id': '1721119594914734080',
#    'id': '1886103172634288175',
#    'created_at': '2025-02-02T17:23:33.000Z',
#    'edit_history_tweet_ids': ['1886103172634288175']},
#   {'text': 'Skip dulu deh, Mas. Nggak bisa nyanyi soalnya. Tapi kalau butuh plus one kabarin ya, lumayan makan siang gratis. https://t.co/c3aUySXy3e',
#    'author_id': '3262933376',
#    'id': '1886102669363970526',
#    'created_at': '2025-02-02T17:21:33.000Z',
#    'edit_history_tweet_ids': ['1886102669363970526']},
#   {'text': 'harapannya si efisiensi ini udah dikalkulasi utk dialihkan ke program-program yg emang signifikan buat kita ya. tapi kalo muara dana efisiensi ini ke program maksa banget ges alias mbg itu.. super mega big jumbo gws deh, semua aja kena caplok',
#    'author_id': '948218930677530624',
#    'id': '1886102341532975214',
#    'created_at': '2025-02-02T17:20:14.000Z',
#    'edit_history_tweet_ids': ['1886102341532975214']},
#   {'text': '@kompascom Tahu gak kenapa LPG jadi dipersulit? \n\nSemua gara2 program gak mutu Makan Bergizi Gratis. Semua sector dibabat hanya buat program gak jelas gini yg anggaranya ratusan milyar perbulannya',
#    'author_id': '930239024740024320',
#    'id': '1886102210016415824',
#    'created_at': '2025-02-02T17:19:43.000Z',
#    'edit_history_tweet_ids': ['1886102210016415824']},
#   {'text': '@BudiBukanIntel @abulmuzaffar10 Sebenernya di kondisi ideal, makan siang gratis ini gerakin ekonomi makro secara signifikan, belanja negara endingnya ke pedagang, petani, peternak, nelayan lokal bisa jual barang\nNiatnya utk menciptakan demand lokal utk kebutuhan pokok\nTapi balik lagi, jika dalam kondisi ideal',
#    'author_id': '1355781108898570244',
#    'id': '1886102193096241310',
#    'created_at': '2025-02-02T17:19:39.000Z',
#    'edit_history_tweet_ids': ['1886102193096241310']},
#   {'text': 'Gas langka, bensin swasta kosong, MBG bapuk, tukin dosen ga dibayar, pengangguran banyak, pejabat pada banyak duit ga ada hasil. Kapan ini negara seenggaknya ga minus kelakuannya',
#    'author_id': '600813447',
#    'id': '1886101901084860540',
#    'created_at': '2025-02-02T17:18:29.000Z',
#    'edit_history_tweet_ids': ['1886101901084860540']},
#   {'text': '@abulmuzaffar10 @BudiBukanIntel Ikn lebih ga make sense sepertinya 😅, sedipaksanya MBG hasilnya masih cukup real dan bisa dirasain lgsg. Tp kalo untuk kualitas dan keberlangsungan di jangka panjang sulit juga si 😅',
#    'author_id': '248035920',
#    'id': '1886101400788275314',
#    'created_at': '2025-02-02T17:16:30.000Z',
#    'edit_history_tweet_ids': ['1886101400788275314']},
#   {'text': '@tanyakanrl Gua digaji seminggu 100ribu PKL di walikota, dapet makan siang gratis juga 😄',
#    'author_id': '1162131801873117184',
#    'id': '1886097910770934231',
#    'created_at': '2025-02-02T17:02:38.000Z',
#    'edit_history_tweet_ids': ['1886097910770934231']},
#   {'text': '@OggyZilly43173 @kompascom @kumparan semoga gizi anak-anak semakin terpenuhi dengan adanya MBG',
#    'author_id': '1663461185587658753',
#    'id': '1886097429961003172',
#    'created_at': '2025-02-02T17:00:43.000Z',
#    'edit_history_tweet_ids': ['1886097429961003172']},
#   {'text': 'Program MBG jangan hanya untuk memenuhi janji kampanye, tetapi harus dengan kajian yang komprehensif. Bila pelaksanaan tidak cermat bisa saja  timbul permasalahan baru terkait penggunaan anggaran distribusi maupun substansi menu makan yang beragam,bergizi, seimbang,aman dan halal',
#    'author_id': '336144996',
#    'id': '1886097050036740566',
#    'created_at': '2025-02-02T16:59:13.000Z',
#    'edit_history_tweet_ids': ['1886097050036740566']},
#   {'text': '@AnKiiim_ @prabowo Semua krn demi mbg',
#    'author_id': '74346926',
#    'id': '1886097036644372990',
#    'created_at': '2025-02-02T16:59:10.000Z',
#    'edit_history_tweet_ids': ['1886097036644372990']},
#   {'text': 'Tanggapan anak SMA terhadap program makan siang gratis #makansianggratis... https://t.co/TbdTVse1oS lewat @YouTube',
#    'author_id': '1460164345225117697',
#    'id': '1886096945913221560',
#    'created_at': '2025-02-02T16:58:48.000Z',
#    'edit_history_tweet_ids': ['1886096945913221560']},
#   {'text': '@kartikaji iya...multiplier effect nya cuman ke vendor MBG 🙈🙈.... MBG lelang gak sih??gak mungkin swakelola kan...yg ambil vendor soale',
#    'author_id': '39253982',
#    'id': '1886096743244403004',
#    'created_at': '2025-02-02T16:58:00.000Z',
#    'edit_history_tweet_ids': ['1886096743244403004']},
#   {'text': '@AgungLa03498428 @kompascom @tribunnews semoga gizi anak-anak semakin terpenuhi dengan adanya MBG',
#    'author_id': '1663461185587658753',
#    'id': '1886096717692785069',
#    'created_at': '2025-02-02T16:57:54.000Z',
#    'edit_history_tweet_ids': ['1886096717692785069']},
#   {'text': '@OggyZilly43173 @kompascom @kumparan @tribunnews semoga gizi anak-anak semakin terpenuhi dengan adanya MBG',
#    'author_id': '1663461185587658753',
#    'id': '1886096268675649853',
#    'created_at': '2025-02-02T16:56:07.000Z',
#    'edit_history_tweet_ids': ['1886096268675649853']},
#   {'text': '@hnirankara mas , yg mau bayar lho banyak mas , kok kamu mikir gratis , makan bergizi gratis di nyinyirin , toll bayar juga di nyinyirin? trus maunya makan bergizi bayar - toll nya yg gratis gitu taa ?? gimana kamu mas , lagipula sejak jaman siapa toll gratis mas ?',
#    'author_id': '1186247602708205568',
#    'id': '1886096104082846045',
#    'created_at': '2025-02-02T16:55:27.000Z',
#    'edit_history_tweet_ids': ['1886096104082846045']},
#   {'text': '@salmonchizumiso @tanyarlfes Hal yang gak tepat sasaran memang sering terjadi ditiap progam kak, kebijakan anggaran yang terbatas juga berpengaruh, tapi kalau mau diperbaiki, perangkat daerah sana juga harus bisa bantu pemerintah menyeleksi sekolah mana yang paling membutuhkan MBG tsb',
#    'author_id': '1329427643930869761',
#    'id': '1886095328287617525',
#    'created_at': '2025-02-02T16:52:22.000Z',
#    'edit_history_tweet_ids': ['1886095328287617525']},
#   {'text': '@CNNIndonesia Naik kemana hadeuh loh ya kalo memang harus di evaluasi kembali program ini ya di evaluasi dan di revisi, fokuskan MBG ke daerah2x pelosok, daerah miskin dan tertinggal yang bener2x membutuhkan',
#    'author_id': '1486658974388678656',
#    'id': '1886095286600425727',
#    'created_at': '2025-02-02T16:52:12.000Z',
#    'edit_history_tweet_ids': ['1886095286600425727']},
#   {'text': '@Mdy_Asmara1701 Alasan agar tepat sasaran, tapi malah menyusahkan rakyat. \nMBG apa sudah tepat sasaran ? Anak orang kaya naik mobil Alphard, Pajero, Fortuner ke sekolah dikasih MBG malah jijik. Kalau MBG utk daerah tertinggal/miskin okelah.\nWo Wo... gimana program mu nih..\nMenterinya pun bego..',
#    'author_id': '1217745302502821892',
#    'id': '1886095126747115931',
#    'created_at': '2025-02-02T16:51:34.000Z',
#    'edit_history_tweet_ids': ['1886095126747115931']},
#   {'text': 'Anak Harus Cukup Makan: Prabowo dan Misi Makan Bergizi Gratis Sejak 2006! \n\nhttps://t.co/E7COqNEkqk',
#    'author_id': '833782256837681152',
#    'id': '1886094722013507667',
#    'created_at': '2025-02-02T16:49:58.000Z',
#    'edit_history_tweet_ids': ['1886094722013507667']},
#   {'text': '@soundofrae Butuh makan siang gratis ✨️',
#    'author_id': '1426885379571863552',
#    'id': '1886094560969081232',
#    'created_at': '2025-02-02T16:49:19.000Z',
#    'edit_history_tweet_ids': ['1886094560969081232']},
#   {'text': 'BGN Sosialisasi Makan Bergizi Gratis, Alifudin PKS: Harus Perhatikan Kualitas\n\nhttps://t.co/wO6TbwmBmQ',
#    'author_id': '79130206',
#    'id': '1886093680882417666',
#    'created_at': '2025-02-02T16:45:50.000Z',
#    'edit_history_tweet_ids': ['1886093680882417666']},
#   {'text': '@tanyarlfes karena subsidi buat lpgnya mo dicabut, dipake buat program makan siang gratis... thanks to kaum 52 ye😏',
#    'author_id': '134693208',
#    'id': '1886093216883282235',
#    'created_at': '2025-02-02T16:43:59.000Z',
#    'edit_history_tweet_ids': ['1886093216883282235']},
#   {'text': '79 th Indonesia merdeka dan 10 thn pemerintahan Jokowi cuma bikin masyarakat dan anak2 lapar kurang gizi ..... Anwar Abbas Wanti-wanti MBG Jangan Sampai Jadi “Program Kenyang” Buat Konglomerat! https://t.co/zMvWxQnZvu',
#    'author_id': '1754796187893514240',
#    'id': '1886092713730412957',
#    'created_at': '2025-02-02T16:41:59.000Z',
#    'edit_history_tweet_ids': ['1886092713730412957']},
#   {'text': '@wannafigh @eexxoo_7 kalo saya pelajari Indonesia sdh jatuh di tangan GE sejak 1965.\nsama seperti Jepang. secara publik Jepang Negara berdaulat tapi di belakang sdh di rante seperti seekor kuda gak bisa melawan. \nMelawan... Tsunami Aceh.\n MBG itu agenda GE. \nMentri kesehatan... tahu khan?',
#    'author_id': '1154478487',
#    'id': '1886092608352743569',
#    'created_at': '2025-02-02T16:41:34.000Z',
#    'edit_history_tweet_ids': ['1886092608352743569']},
#   {'text': '@kegblgnunfaedh Njay tangannya udah siap nabok orang yang bilang makan siang gratis ga enak',
#    'author_id': '1852573739248160768',
#    'id': '1886092287425622524',
#    'created_at': '2025-02-02T16:40:17.000Z',
#    'edit_history_tweet_ids': ['1886092287425622524']},
#   {'text': '@tanyakanrl harusnya akar masalahnya yg diselesaikan, makan siang gratis itu solusi yg kurang tepat.',
#    'author_id': '1129876343276081154',
#    'id': '1886091874873770331',
#    'created_at': '2025-02-02T16:38:39.000Z',
#    'edit_history_tweet_ids': ['1886091874873770331']},
#   {'text': 'MBG Pertumbuhan Ekonomi, Hasim Pede Ekonomi Tumbuh 9 Persen Berkat Makan Bergizi Gratis #MBGDorongEkonomi https://t.co/3WVEuKbJf7',
#    'author_id': '1283264969513906176',
#    'id': '1886091542806597728',
#    'created_at': '2025-02-02T16:37:20.000Z',
#    'edit_history_tweet_ids': ['1886091542806597728']},
#   {'text': 'PLN sebagai BUMN terus mendukung penuh program Makan Bergizi Gratis (MBG) dari Pemerintah ini dengan memastikan pasokan listrik andal di 238 titik Satuan Pelayanan Pemenuhan Gizi (SPPG) di 31 provinsi.\n\n#AstaCitaPemerintah #MakanBergiziGratis\n #AnakGenerasiEmas #PLNDukungMBG https://t.co/UihXbjTndr',
#    'author_id': '1769750292311265280',
#    'id': '1886091180775256097',
#    'created_at': '2025-02-02T16:35:54.000Z',
#    'edit_history_tweet_ids': ['1886091180775256097']},
#   {'text': 'MBG Pertumbuhan Ekonomi, Hasim Pede Ekonomi Tumbuh 9 Persen Berkat Makan Bergizi Gratis #MBGDorongEkonomi https://t.co/8p3evHerP6',
#    'author_id': '1283264969513906176',
#    'id': '1886091179646964110',
#    'created_at': '2025-02-02T16:35:53.000Z',
#    'edit_history_tweet_ids': ['1886091179646964110']},
#   {'text': "Efisiensi apbd, yg di-cut layanan transportasi publik. Okaaayy 58%, i hope y'all satisfied with this. Yg penting dapat makan siang gratis ygy? https://t.co/ttVJxqMG5N",
#    'author_id': '177405510',
#    'id': '1886090952038920293',
#    'created_at': '2025-02-02T16:34:59.000Z',
#    'edit_history_tweet_ids': ['1886090952038920293']},
#   {'text': '@sspidercat emyu mending jadi relawan makan siang gratis aja kata w mah len',
#    'author_id': '1270401029318705152',
#    'id': '1886090661277082071',
#    'created_at': '2025-02-02T16:33:50.000Z',
#    'edit_history_tweet_ids': ['1886090661277082071']},
#   {'text': '@fantytjin @yanuarnugroho Salah lo, ya udah jelas hapus program MBG. Program memaksa, menyedot anggaran besar, efek domino nya berbahaya',
#    'author_id': '2801765519',
#    'id': '1886089287671877808',
#    'created_at': '2025-02-02T16:28:22.000Z',
#    'edit_history_tweet_ids': ['1886089287671877808']},
#   {'text': '@3usri Daripada makan menu makan siang gratis mending ga makan lagi 6 hari',
#    'author_id': '247651184',
#    'id': '1886088616340037788',
#    'created_at': '2025-02-02T16:25:42.000Z',
#    'edit_history_tweet_ids': ['1886088616340037788']},
#   {'text': '@detikcom makan siang gratis bukan???',
#    'author_id': '1512841902282133510',
#    'id': '1886088515387376105',
#    'created_at': '2025-02-02T16:25:18.000Z',
#    'edit_history_tweet_ids': ['1886088515387376105']},
#   {'text': 'Jadi inget pas pertama kali jd intern gaji gue berupaa makan siang gratis https://t.co/uJ5Nir6Wfg',
#    'author_id': '1438365659872706561',
#    'id': '1886088367584022606',
#    'created_at': '2025-02-02T16:24:43.000Z',
#    'edit_history_tweet_ids': ['1886088367584022606']},
#   {'text': '@rzlhmdfz dampak program makan siang gratis ga nyampe kantor ya gitu😢',
#    'author_id': '1220006991130591232',
#    'id': '1886088351490711784',
#    'created_at': '2025-02-02T16:24:39.000Z',
#    'edit_history_tweet_ids': ['1886088351490711784']},
#   {'text': 'Sori eonnie2 ,,,, klw mngecewakan ,,,,\n\nBut u guys hv 2 kno ,,,, ingfo pntink ,,,,, yg kmi konsumsi ,,,,, hnylh makan siang gratis program pemerentah🫡🫡🫡🫡\n\nNeks taim bleh tlg trf 100jt iyh per member utk maknae2 bokem enih ,,, agar kmi smakin KAYA RAYA n TETAP LUCU N IMUT🪭💸! https://t.co/kKndzVsput',
#    'author_id': '1878819444895752192',
#    'id': '1886087808932360243',
#    'created_at': '2025-02-02T16:22:30.000Z',
#    'edit_history_tweet_ids': ['1886087808932360243']},
#   {'text': 'Biar apa? Ya biar kita bergantung ke bansos lg lhaa, biar kita dukung tu program MBG soalnya gasnya langkaaaa jd gabisa masak, lagu lama inimah https://t.co/lgVPpI33zX',
#    'author_id': '899644787443159040',
#    'id': '1886087611485425940',
#    'created_at': '2025-02-02T16:21:43.000Z',
#    'edit_history_tweet_ids': ['1886087611485425940']},
#   {'text': '@Dhruyv Takut disuruh makan siang gratis',
#    'author_id': '3493438872',
#    'id': '1886087257481978277',
#    'created_at': '2025-02-02T16:20:18.000Z',
#    'edit_history_tweet_ids': ['1886087257481978277']},
#   {'text': '@8ilmoure @Miladiysa Makan siang gratis.',
#    'author_id': '298373887',
#    'id': '1886085675952529619',
#    'created_at': '2025-02-02T16:14:01.000Z',
#    'edit_history_tweet_ids': ['1886085675952529619']},
#   {'text': '@kangmusss3 @PNS_Garis_Lucu @BetaEpsilonPhi @pejabrut Semua demi anak makan siang gratis, tp bikin orang tuanya yg kerepotan. awokwokwokwok',
#    'author_id': '1002326942803038208',
#    'id': '1886085648639221809',
#    'created_at': '2025-02-02T16:13:55.000Z',
#    'edit_history_tweet_ids': ['1886085648639221809']},
#   {'text': '@hyewoose aku lanhsung keinget bajnaj kakk!! dan topiknya ttg mbg itu😭🫵🏼 pdhl bagus naikin awareness biar ga iya iya sm program yg kagak jelas',
#    'author_id': '1421852713235587074',
#    'id': '1886084841252532525',
#    'created_at': '2025-02-02T16:10:42.000Z',
#    'edit_history_tweet_ids': ['1886084841252532525']},
#   {'text': 'Lihatlah program MBG. Demi makan siang gratis yg gk ada jaminan bakalan makan gratis lagi selain itu, negara menghabiskan triliunan dan cut costs bagi sektor lain. Kesehatan dan pendidikan dianggap sebagai prioritas pendukung\n\nAmanat UUD 1945: "mencerdaskan kehidupan bangsa"?????',
#    'author_id': '1336163342147153920',
#    'id': '1886084766707179804',
#    'created_at': '2025-02-02T16:10:24.000Z',
#    'edit_history_tweet_ids': ['1886084766707179804']},
#   {'text': '@tanyakanrl mbg juga ga bnr, banyak anak yang picky eater jadi food waste. Kalau semisal pakai sekala prioritas sih masi oke ya, sebar ke daerah tertinggal dan anak-anak yang membutuhkan lebih ada manfaatnya. Aneh jg pendidikan dan kesehatan ga masuk prioritas, gmn si pemikirannya heran',
#    'author_id': '1603777392291745792',
#    'id': '1886084224660435121',
#    'created_at': '2025-02-02T16:08:15.000Z',
#    'edit_history_tweet_ids': ['1886084224660435121']},
#   {'text': 'Kata gue mah sumpah dah, udah berhentiin aja makan siang gratis ini pls😭',
#    'author_id': '1016511387734949889',
#    'id': '1886084194012672149',
#    'created_at': '2025-02-02T16:08:08.000Z',
#    'edit_history_tweet_ids': ['1886084194012672149']},
#   {'text': '@altriutari uangnya dipake program makan siang gratis',
#    'author_id': '1239571743645155328',
#    'id': '1886083693577638279',
#    'created_at': '2025-02-02T16:06:08.000Z',
#    'edit_history_tweet_ids': ['1886083693577638279']},
#   {'text': 'Semoga besok sudah di realisasikan... Makan Bergizi Gratis.. dgn menu baru Belalang &amp; ulat sagu.. bagaimana dgn Daerah kalian..?? 🦗🐛😅\n\nNi aki2 kelas berapa emangnya? https://t.co/TEqoaPxxT0',
#    'author_id': '178600446',
#    'id': '1886083586123800707',
#    'created_at': '2025-02-02T16:05:43.000Z',
#    'edit_history_tweet_ids': ['1886083586123800707']},
#   {'text': '@AirinDatangLagi KLo mo jadi pengecer khusus yg berduit karena pemerintah butuh dana tunai buat beli beras sayur ikan asin tempe tahu susu uht program MBG https://t.co/saSV4NWMWq',
#    'author_id': '1603619423205539840',
#    'id': '1886083583502418247',
#    'created_at': '2025-02-02T16:05:42.000Z',
#    'edit_history_tweet_ids': ['1886083583502418247']},
#   {'text': '@AsadBisyir itu kiper apa vendor makan bergizi gratis Pak?',
#    'author_id': '349200613',
#    'id': '1886083415507910759',
#    'created_at': '2025-02-02T16:05:02.000Z',
#    'edit_history_tweet_ids': ['1886083415507910759']},
#   {'text': '@DokterTifa @prabowo Jangan gara-gara "MBG CEBAN"\nTapi beban Rakyat bertambah :\n▪️Pajak Naik\n▪️Gas Melon 3 kg jadi 25 rb\n▪️BPJS sulit\n▪️Sembako mahal\n▪️Ongkos transport naik\n\nOk Gas... \nOk Gas...',
#    'author_id': '1680052893217591296',
#    'id': '1886082925441233207',
#    'created_at': '2025-02-02T16:03:05.000Z',
#    'edit_history_tweet_ids': ['1886082925441233207']},
#   {'text': '@DavidWijaya82 Intinya pemerintah butuh dana tunai buat beli sayur telur ikan teri  tempe tahu atasi program PSN MBG makanya yg jadi pengecer harus yg berduit https://t.co/4uL18S67R0',
#    'author_id': '1603619423205539840',
#    'id': '1886082555201683737',
#    'created_at': '2025-02-02T16:01:37.000Z',
#    'edit_history_tweet_ids': ['1886082555201683737']},
#   {'text': '@soundoncoups @1 REAL BANG. Gw denger teriakan abang yang paling kenceng, disambut air mata abe yang membanjiri venue 😌 salken abang! Kira-kira kalau dipanggil sama prabowo n mayted bakal dapet MBG juga ga ya..... /kepengen',
#    'author_id': '1354045151325245440',
#    'id': '1886082234656096408',
#    'created_at': '2025-02-02T16:00:21.000Z',
#    'edit_history_tweet_ids': ['1886082234656096408']},
#   {'text': 'Namun kenyataannya, MBG sering terjebak dalam rutinitas yang hanya "mengisi perut," bukan menyelesaikan masalah sesungguhnya.',
#    'author_id': '1834753165482504192',
#    'id': '1886082214347030808',
#    'created_at': '2025-02-02T16:00:16.000Z',
#    'edit_history_tweet_ids': ['1886082214347030808']},
#   {'text': 'Ah, Program Makan Bergizi Gratis (MBG)! Sebuah inisiatif yg seharusnya jadi solusi, tapi lebih sering jadi bahan perdebatan. Sebagai sebuah program yang tujuannya mulia, tentunya siapa pun ingin mendukung jika itu benar-benar berjalan dengan baik. \n\nSehelai benang: (jangan baper) https://t.co/FNqkrmuM0P',
#    'author_id': '1834753165482504192',
#    'id': '1886082211864359284',
#    'created_at': '2025-02-02T16:00:15.000Z',
#    'edit_history_tweet_ids': ['1886082211864359284']},
#   {'text': '@lookatntf gak boleh gitu, nanti gak dapet makan siang gratis',
#    'author_id': '403247100',
#    'id': '1886081666911006874',
#    'created_at': '2025-02-02T15:58:05.000Z',
#    'edit_history_tweet_ids': ['1886081666911006874']},
#   {'text': 'juun mirip bgt mbg joy😭',
#    'author_id': '1542868932758974465',
#    'id': '1886081584044118488',
#    'created_at': '2025-02-02T15:57:45.000Z',
#    'edit_history_tweet_ids': ['1886081584044118488']},
#   {'text': 'Dulu Zaman SBY minyak tanah dikonversi dgn  LPG 3kg rakyat manut\nSekarang LPG 3kg disalurkan khusus untuk yg berduit karena pemerintah butuh dana tunai buat program PSN MBG jadi rakyat harus manut KLo ga berduit jgn harap berbisnis LPG 3kg https://t.co/mVRjxGm1rz',
#    'author_id': '1603619423205539840',
#    'id': '1886081163019870336',
#    'created_at': '2025-02-02T15:56:05.000Z',
#    'edit_history_tweet_ids': ['1886081163019870336']},
#   {'text': 'Hasyim Akui Anies Lebih Dulu Gulirkan Makan Bergizi Gratis Dibanding Prabowo\n\nhttps://t.co/OMkZDI6SKd https://t.co/1z6ZLV3oan',
#    'author_id': '1828465190356295682',
#    'id': '1886081125816439203',
#    'created_at': '2025-02-02T15:55:56.000Z',
#    'edit_history_tweet_ids': ['1886081125816439203']},
#   {'text': 'Kebijakan pemerintah ini ga koheren sama sekali, gw ngebayangin reaksi penganut ideologi kayak…\n\nPro kiri:\n\n*Makan siang gratis*\n👩🏼: Keren!\n\n*PPN naik*\n👩🏼 : make sense, perlu untuk support program\n\n*LPG subsidi dibatas*\n👩🏼: lah?!',
#    'author_id': '603625724',
#    'id': '1886080874674032644',
#    'created_at': '2025-02-02T15:54:56.000Z',
#    'edit_history_tweet_ids': ['1886080874674032644']},
#   {'text': '@mariousyo Jdi si biskita diberhentikan dulu krn prioritasin program makan siang gratis?? Keputusan pemda kah?',
#    'author_id': '1405361481869262852',
#    'id': '1886080286578069846',
#    'created_at': '2025-02-02T15:52:36.000Z',
#    'edit_history_tweet_ids': ['1886080286578069846']},
#   {'text': '@abulmuzaffar10 Harus di challenge memang gagasan makan siang gratis.',
#    'author_id': '996908004833464322',
#    'id': '1886079985187979505',
#    'created_at': '2025-02-02T15:51:24.000Z',
#    'edit_history_tweet_ids': ['1886079985187979505']},
#   {'text': '@tanyarlfes gedean ego lu daripada budget makan siang gratis',
#    'author_id': '1120974408888139776',
#    'id': '1886079593012195466',
#    'created_at': '2025-02-02T15:49:51.000Z',
#    'edit_history_tweet_ids': ['1886079593012195466']},
#   {'text': '@DokterTifa @prabowo Lebih baik Uang MBG dialokasikan utk tambahan subsidi :\n▪️BPJS\n▪️Gas Melon 3 kg\n▪️Sembako murah\n▪️Pendidikan Gratis\n▪️Bangun Jalan &amp; Jembatan\n\nLebih bermanfaat...',
#    'author_id': '1680052893217591296',
#    'id': '1886079274232516951',
#    'created_at': '2025-02-02T15:48:35.000Z',
#    'edit_history_tweet_ids': ['1886079274232516951']},
#   {'text': '@DokterTifa Info yg didapat :\n1. Tambahan dana 100T MBG di dpt dari pemotongan anggaran K/L\n2 &amp; 3. Giant Sea Wall hanya dibangun pada titik tertentu penghasil ROB sehingga tdk mengganggu aktivitas nelayan dan kegiatan laut lainnya serta abrasif.\nGood luck.',
#    'author_id': '1730955716117327872',
#    'id': '1886079246860468676',
#    'created_at': '2025-02-02T15:48:28.000Z',
#    'edit_history_tweet_ids': ['1886079246860468676']},
#   {'text': 'MAKAN BERGIZI GRATIS\nMakanan bergizi adalah hak setiap orang, dan dengan program makan gratis ini, kita bisa memastikan semua orang mendapatkan gizi yang mereka butuhkan untuk hidup sehat.\n#PenuhiGiziIndonesia #Indonesiaemas #AstaCita #Indonesiamaju #GiziBaik #MakananBergizi https://t.co/vFw1gwTglc',
#    'author_id': '1729543339341733888',
#    'id': '1886079213972947023',
#    'created_at': '2025-02-02T15:48:20.000Z',
#    'edit_history_tweet_ids': ['1886079213972947023']},
#   {'text': 'Makan Bergizi Gratis\nTujuan utama dari Program MBG adalah untuk mengurangi angka malnutrisi dan stunting yang masih menjadi permasalahan serius di Indonesia, khususnya pada kelompok rentan.\n#PenuhiGiziIndonesia #Indonesiaemas #AstaCita #Indonesiamaju #GiziBaik #MakananBergizi https://t.co/aepHNx8UD1',
#    'author_id': '1729543339341733888',
#    'id': '1886078923097948419',
#    'created_at': '2025-02-02T15:47:11.000Z',
#    'edit_history_tweet_ids': ['1886078923097948419']},
#   {'text': 'Investasi Masa Depan Makan Bergizi Gratis\n"HARI INI MAKAN SEHAT, ESOK JADI HEBAT!"\n"AYO DUKUNG GENERASI CERDAS ACEH DENGAN GIZI BERKUALITAS"\n#PenuhiGiziIndonesia #Indonesiaemas #AstaCita #Indonesiamaju #GiziBaik #MakananBergizi https://t.co/ScfgttHWN9',
#    'author_id': '1729543339341733888',
#    'id': '1886078702460796941',
#    'created_at': '2025-02-02T15:46:18.000Z',
#    'edit_history_tweet_ids': ['1886078702460796941']},
#   {'text': '@PNS_Ababil Udah makan blom? makan bergizi gratis',
#    'author_id': '73836199',
#    'id': '1886078604662223336',
#    'created_at': '2025-02-02T15:45:55.000Z',
#    'edit_history_tweet_ids': ['1886078604662223336']},
#   {'text': 'Program Makan Bergizi Gratis Makan Bergizi, Hidup Lebih Berarti!\n#PenuhiGiziIndonesia #Indonesiaemas #AstaCita #Indonesiamaju #GiziBaik #MakananBergiz https://t.co/tAERVu4633',
#    'author_id': '1729543339341733888',
#    'id': '1886078567026729159',
#    'created_at': '2025-02-02T15:45:46.000Z',
#    'edit_history_tweet_ids': ['1886078567026729159']},
#   {'text': 'Program makan bergizi gratis memberikan manfaat untuk memenuhi gizi nasional. Program ini bertujuan untuk meningkatkan gizi anak-anak Indonesia, khususnya di daerah pedalaman yang rentan terhadap stunting dan malnutrisi.\n\n#PenuhiGiziIndonesia https://t.co/YU4eIv1tv5',
#    'author_id': '1575473598805835776',
#    'id': '1886076672828649534',
#    'created_at': '2025-02-02T15:38:15.000Z',
#    'edit_history_tweet_ids': ['1886076672828649534']},
#   {'text': 'Program makan bergizi gratis memberikan manfaat untuk memenuhi gizi nasional. Program ini bertujuan untuk meningkatkan gizi anak-anak Indonesia, khususnya di daerah pedalaman yang rentan terhadap stunting dan malnutrisi.\n\n#PenuhiGiziIndonesia https://t.co/3VxVdCgAGD',
#    'author_id': '1575473598805835776',
#    'id': '1886076645750325506',
#    'created_at': '2025-02-02T15:38:08.000Z',
#    'edit_history_tweet_ids': ['1886076645750325506']},
#   {'text': 'Program makan bergizi gratis memberikan manfaat untuk memenuhi gizi nasional. Program ini bertujuan untuk meningkatkan gizi anak-anak Indonesia, khususnya di daerah pedalaman yang rentan terhadap stunting dan malnutrisi.\n\n#PenuhiGiziIndonesia https://t.co/pKV03oXGBz',
#    'author_id': '1575473598805835776',
#    'id': '1886076615920333229',
#    'created_at': '2025-02-02T15:38:01.000Z',
#    'edit_history_tweet_ids': ['1886076615920333229']},
#   {'text': 'Program makan bergizi gratis memberikan manfaat untuk memenuhi gizi nasional. Program ini bertujuan untuk meningkatkan gizi anak-anak Indonesia, khususnya di daerah pedalaman yang rentan terhadap stunting dan malnutrisi.\n\n#PenuhiGiziIndonesia https://t.co/cOH2RHMvmN',
#    'author_id': '1575473598805835776',
#    'id': '1886076570705748131',
#    'created_at': '2025-02-02T15:37:50.000Z',
#    'edit_history_tweet_ids': ['1886076570705748131']},
#   {'text': 'Program makan bergizi gratis memberikan manfaat untuk memenuhi gizi nasional. Program ini bertujuan untuk meningkatkan gizi anak-anak Indonesia, khususnya di daerah pedalaman yang rentan terhadap stunting dan malnutrisi.\n\n#PenuhiGiziIndonesia https://t.co/c9Cb1d2ZDR',
#    'author_id': '1575473598805835776',
#    'id': '1886076546613678163',
#    'created_at': '2025-02-02T15:37:44.000Z',
#    'edit_history_tweet_ids': ['1886076546613678163']},
#   {'text': 'fokus makan siang gratis, efisiensi anggaran, ga jadi pindah ke ikn, terus ini lah itu lah... kayak... will all of us stay alive for next few years!?',
#    'author_id': '1266632075047612416',
#    'id': '1886076228345712898',
#    'created_at': '2025-02-02T15:36:29.000Z',
#    'edit_history_tweet_ids': ['1886076228345712898']},
#   {'text': '@yanuarnugroho Sy kok gak yakin ini penghematan, cm mengalihkan alokasi anggaran ke tempat lain, untuk nambah MBG kah?',
#    'author_id': '1641926009246330880',
#    'id': '1886076193243615648',
#    'created_at': '2025-02-02T15:36:20.000Z',
#    'edit_history_tweet_ids': ['1886076193243615648']},
#   {'text': '@shagreshy tanggapan soal makan siang gratis',
#    'author_id': '773623180862820353',
#    'id': '1886075103387308525',
#    'created_at': '2025-02-02T15:32:00.000Z',
#    'edit_history_tweet_ids': ['1886075103387308525']},
#   {'text': '@AgusHerd @abulmuzaffar10 Selama kampanye banyak yg kliatan asal bunyi dan akhirnya ditunda. Nah mbg doang yg di push, artinya kan udh dipersiapkan',
#    'author_id': '1863895818467774464',
#    'id': '1886075012593152078',
#    'created_at': '2025-02-02T15:31:39.000Z',
#    'edit_history_tweet_ids': ['1886075012593152078']},
#   {'text': '@liezz_she @rastomosuwardi @CNNIndonesia Ya kantin emang bisnis, tp beda level sama mitra di program MBG. Dan yg pasti klo kantin klo di lingkungan sekolah jd memberdayakan usaha yg udah ada, tp diperbaiki lagi standarnya. Ada kok standar kantin sehat harus gimana.',
#    'author_id': '1504586649006534692',
#    'id': '1886074976731885998',
#    'created_at': '2025-02-02T15:31:30.000Z',
#    'edit_history_tweet_ids': ['1886074976731885998']},
#   {'text': 'ARGHHH ADA MAKAN SIANG GRATIS? https://t.co/JxIrghBH0v',
#    'author_id': '1674512503',
#    'id': '1886074895509180468',
#    'created_at': '2025-02-02T15:31:11.000Z',
#    'edit_history_tweet_ids': ['1886074895509180468']},
#   {'text': 'Pertanyaan:\n\nSatu\nUang dari mana? Sedangkan untuk MBG saja Presiden utang kemana-mana? Apakah barter dengan Proyek Reklamasinya 9 Naga?\n\nDua\nBagaimana cara Nelayan Pantai Utara Jawa dari Banten hingga Jawa Timur melaut kalau di depan laut ada  tanggul raksasa? \n\nTiga\nApakah benar… https://t.co/m4RO7krD2L',
#    'author_id': '1502822366946402304',
#    'id': '1886073517105615051',
#    'created_at': '2025-02-02T15:25:42.000Z',
#    'edit_history_tweet_ids': ['1886073517105615051']},
#   {'text': '@tanyarlfes Pemerintah lg ngaco krn kemungkinan besar buat sediain dana MBG (makan bergizi gratis) tau sendiri lah bau2nya program itu butuh cash besar jadi dicari-cari sumber dari mana? Salah satu sasaran ya LPG melon. Pada saat masyarakat sudah ketergantungan justru dipersulit namanya… https://t.co/Cs7YAlSpJW',
#    'author_id': '1584677450',
#    'id': '1886072637727932668',
#    'created_at': '2025-02-02T15:22:13.000Z',
#    'edit_history_tweet_ids': ['1886072637727932668']},
#   {'text': '@4leci4 Cuma berharap menu makan bergizi gratis standard minimalnya seperti masakan njenengan begini, ikhlas aku dipotong pajak. AMIN🙏🙏🙏',
#    'author_id': '1722079575449194496',
#    'id': '1886072595990397132',
#    'created_at': '2025-02-02T15:22:03.000Z',
#    'edit_history_tweet_ids': ['1886072595990397132']},
#   {'text': '@tham878 NTAR JUGA JADI HUTAN LAGI, MENDINGAN DUITNYA BUAT BIAYAI MBG 🤣🤣🤣',
#    'author_id': '44305269',
#    'id': '1886072540587778203',
#    'created_at': '2025-02-02T15:21:49.000Z',
#    'edit_history_tweet_ids': ['1886072540587778203']},
#   {'text': '@Mdy_Asmara1701 Makan bergizi gratis ❌\nMakan JANJI gratis ✅',
#    'author_id': '86069916',
#    'id': '1886071416539496672',
#    'created_at': '2025-02-02T15:17:21.000Z',
#    'edit_history_tweet_ids': ['1886071416539496672']},
#   {'text': 'Pemodal Besar di Balik Makan Bergizi Gratis https://t.co/m12m9Glk2n',
#    'author_id': '1345661143398793216',
#    'id': '1886070996521857119',
#    'created_at': '2025-02-02T15:15:41.000Z',
#    'edit_history_tweet_ids': ['1886070996521857119']},
#   {'text': '@andiicalilyas Kalo anak yg bilang makan mbg gaenak gmn om',
#    'author_id': '1806328268083339264',
#    'id': '1886070161842778224',
#    'created_at': '2025-02-02T15:12:22.000Z',
#    'edit_history_tweet_ids': ['1886070161842778224']},
#   {'text': 'Program Makan Bergizi Gratis (MBG) di Kota Cimahi, Jawa Barat, kini menjadi contoh nasional dengan pemanfaatan susu segar dari peternak lokal.\xa0\n\nBerita selengkapnya: https://t.co/vlgSOkBojk \n📷: Canva\n\n#mbg #cimahi #susu #peternakan #lokal https://t.co/6Z7DPhTjOh',
#    'author_id': '1443139240515096578',
#    'id': '1886070118826033262',
#    'created_at': '2025-02-02T15:12:12.000Z',
#    'edit_history_tweet_ids': ['1886070118826033262']},
#   {'text': '@ssoooyyaa makan siang gratis adalah nomer satu🗿',
#    'author_id': '1261269074144710656',
#    'id': '1886069709424164938',
#    'created_at': '2025-02-02T15:10:34.000Z',
#    'edit_history_tweet_ids': ['1886069709424164938']},
#   {'text': 'Ini orang bisa ga dana nya dipotong buat program MBG https://t.co/adaEaLohnn',
#    'author_id': '1313450965278715905',
#    'id': '1886068936472748481',
#    'created_at': '2025-02-02T15:07:30.000Z',
#    'edit_history_tweet_ids': ['1886068936472748481']}],
#  'meta': {'newest_id': '1886107824356561286',
#   'oldest_id': '1886068936472748481',
#   'result_count': 99,
#   'next_token': 'b26v89c19zqg8o3frr9sy1q9guf104tt7gxi7y4kmm6pp'}}

# %%
resultdf = pd.DataFrame(columns=['id', 'edit_history_tweet_ids', 'created_at', 'text', 'author_id'])

for i in range(len(json_response['data'])):
    #print(json_response['data'][i])
    insertdf = pd.DataFrame(json_response['data'][i])
    resultdf = pd.concat([resultdf,insertdf])

# %%
resultdf.to_csv(r"dataset/raw/020225_150730sampai174202.csv")

# %%
len(resultdf)
# Out:
# 99
